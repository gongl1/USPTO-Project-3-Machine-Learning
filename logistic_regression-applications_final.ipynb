# %%
# Import dependencies
import pandas as pd

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read in data
df = pd.read_csv("csv_patent_2019/application_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df.dropna(how='all')
df.head()
# Out:
#   application_number filing_date application_invention_type  \
# 0            2000161         NaN                    Utility
# 1            2022946         NaN                    Utility
# 2            2032617         NaN                    Utility
# 3            2045760  1948-08-23                        NaN
# 4            2048602         NaN                        NaN
#
#   examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                NaN               NaN        NaN           NaN
# 1                NaN               NaN        NaN           NaN
# 2                NaN               NaN        NaN           NaN
# 3                NaN               NaN        NaN           NaN
# 4                NaN               NaN        NaN           NaN
#
#    confirm_number atty_docket_number  \
# 0          1014.0                NaN
# 1          1141.0                NaN
# 2          1195.0                NaN
# 3          1267.0                NaN
# 4          1286.0                NaN
#
#                                     appl_status_desc  ... file_location_date  \
# 0                                                NaN  ...         2000-01-21
# 1                                                NaN  ...         2000-01-21
# 2                                                NaN  ...         2000-01-21
# 3  Patented File - (Old Case Added for File Track...  ...         1986-08-11
# 4  Patented File - (Old Case Added for File Track...  ...         2018-11-06
#
#   earliest_pgpub_number earliest_pgpub_date wipo_pub_number wipo_pub_date  \
# 0                   NaN                 NaN             NaN           NaN
# 1                   NaN                 NaN             NaN           NaN
# 2                   NaN                 NaN             NaN           NaN
# 3                   NaN                 NaN             NaN           NaN
# 4                   NaN                 NaN             NaN           NaN
#
#    patent_number patent_issue_date      invention_title  \
# 0            NaN               NaN                  NaN
# 1            NaN               NaN                  NaN
# 2            NaN               NaN                  NaN
# 3        2480888        1949-09-06  BOX STAYING MACHINE
# 4        RE19792        1935-12-17                  NaN
#
#   small_entity_indicator aia_first_to_file
# 0           UNDISCOUNTED               NaN
# 1           UNDISCOUNTED               NaN
# 2           UNDISCOUNTED               NaN
# 3           UNDISCOUNTED             false
# 4           UNDISCOUNTED               NaN
#
# [5 rows x 22 columns]

# %%
df.count()
# Out:
# application_number            15494295
# filing_date                   12252745
# application_invention_type    15489705
# examiner_full_name            10200951
# examiner_art_unit             10753131
# uspc_class                    10762455
# uspc_subclass                 10710592
# confirm_number                12120017
# atty_docket_number            11701457
# appl_status_desc              11903819
# appl_status_date              11903819
# file_location                 15494295
# file_location_date             3513445
# earliest_pgpub_number          6035006
# earliest_pgpub_date            6035006
# wipo_pub_number                3368291
# wipo_pub_date                  4048160
# patent_number                  7069856
# patent_issue_date              7069856
# invention_title               12271828
# small_entity_indicator        12309170
# aia_first_to_file             12252745
# dtype: int64

# %%
# print(df["appl_status_desc"].unique())

# %%
# shift column 'appl_status_desc' to first position
first_column = df.pop('appl_status_desc')

# %%
# insert column using insert(position,column_name,
# first_column) function
df.insert(0, 'appl_status_desc', first_column)

# %%
print("After Shifting column to first position")
display(df)
# Out:
# After Shifting column to first position
#                                            appl_status_desc  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3         Patented File - (Old Case Added for File Track...
# 4         Patented File - (Old Case Added for File Track...
# ...                                                     ...
# 15494290                                                NaN
# 15494291                                                NaN
# 15494292                                                NaN
# 15494293                                                NaN
# 15494294                                                NaN
#
#          application_number filing_date application_invention_type  \
# 0                   2000161         NaN                    Utility
# 1                   2022946         NaN                    Utility
# 2                   2032617         NaN                    Utility
# 3                   2045760  1948-08-23                        NaN
# 4                   2048602         NaN                        NaN
# ...                     ...         ...                        ...
# 15494290     PCT/ZW98/00011         NaN                        PCT
# 15494291     PCT/ZW98/00012         NaN                        PCT
# 15494292     PCT/ZW98/00013         NaN                        PCT
# 15494293     PCT/ZW98/00014         NaN                        PCT
# 15494294      PCTJP05/10844         NaN                        PCT
#
#          examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                       NaN               NaN        NaN           NaN
# 1                       NaN               NaN        NaN           NaN
# 2                       NaN               NaN        NaN           NaN
# 3                       NaN               NaN        NaN           NaN
# 4                       NaN               NaN        NaN           NaN
# ...                     ...               ...        ...           ...
# 15494290                NaN               NaN        NaN           NaN
# 15494291                NaN               NaN        NaN           NaN
# 15494292                NaN               NaN        NaN           NaN
# 15494293                NaN               NaN        NaN           NaN
# 15494294                NaN               NaN        NaN           NaN
#
#           confirm_number atty_docket_number  ... file_location_date  \
# 0                 1014.0                NaN  ...         2000-01-21
# 1                 1141.0                NaN  ...         2000-01-21
# 2                 1195.0                NaN  ...         2000-01-21
# 3                 1267.0                NaN  ...         1986-08-11
# 4                 1286.0                NaN  ...         2018-11-06
# ...                  ...                ...  ...                ...
# 15494290             NaN                NaN  ...                NaN
# 15494291             NaN                NaN  ...                NaN
# 15494292             NaN                NaN  ...                NaN
# 15494293             NaN                NaN  ...                NaN
# 15494294             NaN                NaN  ...                NaN
#
#          earliest_pgpub_number earliest_pgpub_date wipo_pub_number  \
# 0                          NaN                 NaN             NaN
# 1                          NaN                 NaN             NaN
# 2                          NaN                 NaN             NaN
# 3                          NaN                 NaN             NaN
# 4                          NaN                 NaN             NaN
# ...                        ...                 ...             ...
# 15494290                   NaN                 NaN     199907225.0
# 15494291                   NaN                 NaN     199908292.0
# 15494292                   NaN                 NaN     199907980.0
# 15494293                   NaN                 NaN     199908926.0
# 15494294                   NaN                 NaN             NaN
#
#          wipo_pub_date  patent_number patent_issue_date      invention_title  \
# 0                  NaN            NaN               NaN                  NaN
# 1                  NaN            NaN               NaN                  NaN
# 2                  NaN            NaN               NaN                  NaN
# 3                  NaN        2480888        1949-09-06  BOX STAYING MACHINE
# 4                  NaN        RE19792        1935-12-17                  NaN
# ...                ...            ...               ...                  ...
# 15494290    1999-02-18            NaN               NaN                  NaN
# 15494291    1999-02-18            NaN               NaN                  NaN
# 15494292    1999-02-18            NaN               NaN                  NaN
# 15494293    1999-02-25            NaN               NaN                  NaN
# 15494294           NaN            NaN               NaN                  NaN
#
#          small_entity_indicator aia_first_to_file
# 0                  UNDISCOUNTED               NaN
# 1                  UNDISCOUNTED               NaN
# 2                  UNDISCOUNTED               NaN
# 3                  UNDISCOUNTED             false
# 4                  UNDISCOUNTED               NaN
# ...                         ...               ...
# 15494290                    NaN               NaN
# 15494291                    NaN               NaN
# 15494292                    NaN               NaN
# 15494293                    NaN               NaN
# 15494294                    NaN               NaN
#
# [15494295 rows x 22 columns]

# %%
df = df.dropna(subset=['appl_status_desc'])
display(df)
# Out:
#                                            appl_status_desc  \
# 3         Patented File - (Old Case Added for File Track...
# 4         Patented File - (Old Case Added for File Track...
# 7                                             Patented Case
# 8         Patented File - (Old Case Added for File Track...
# 9         Patented File - (Old Case Added for File Track...
# ...                                                     ...
# 15493758     PCT - International Search Report Mailed to IB
# 15493767     PCT - International Search Report Mailed to IB
# 15493776     PCT - International Search Report Mailed to IB
# 15493788     PCT - International Search Report Mailed to IB
# 15493801     PCT - International Search Report Mailed to IB
#
#          application_number filing_date application_invention_type  \
# 3                   2045760  1948-08-23                        NaN
# 4                   2048602         NaN                        NaN
# 7                   2107244  1936-10-23                    Utility
# 8                   2122612  1937-01-27                        NaN
# 9                   2122769  1949-10-21                        NaN
# ...                     ...         ...                        ...
# 15493758     PCT/ZA17/50063  2017-09-13                        PCT
# 15493767     PCT/ZA17/50076  2017-10-08                        PCT
# 15493776     PCT/ZA17/50085  2017-11-22                        PCT
# 15493788     PCT/ZA18/50011  2018-02-22                        PCT
# 15493801     PCT/ZA18/50024  2018-05-16                        PCT
#
#              examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 3                           NaN               NaN        NaN           NaN
# 4                           NaN               NaN        NaN           NaN
# 7            GREGORY, BERNARR E              3662        380        026000
# 8                           NaN               NaN        000        000000
# 9                           NaN               NaN        NaN           NaN
# ...                         ...               ...        ...           ...
# 15493758           YOUNG, LEE W              3902        001        PCT003
# 15493767           YOUNG, LEE W              3902        001        PCT005
# 15493776           YOUNG, LEE W              3902        001        PCT005
# 15493788           YOUNG, LEE W              3902        001        PCT003
# 15493801  COPENHEAVER, BLAINE R              3901        001        PCT004
#
#           confirm_number atty_docket_number  ... file_location_date  \
# 3                 1267.0                NaN  ...         1986-08-11
# 4                 1286.0                NaN  ...         2018-11-06
# 7                 1695.0                NaN  ...         2018-06-23
# 8                 1787.0                NaN  ...         1993-03-16
# 9                 1789.0                NaN  ...         1988-05-03
# ...                  ...                ...  ...                ...
# 15493758          8379.0           P0010PCT  ...                NaN
# 15493767          8746.0            6512PSG  ...                NaN
# 15493776          6160.0            6531OBS  ...                NaN
# 15493788          3071.0              VIBRO  ...                NaN
# 15493801          3690.0           6593BLAW  ...                NaN
#
#          earliest_pgpub_number earliest_pgpub_date wipo_pub_number  \
# 3                          NaN                 NaN             NaN
# 4                          NaN                 NaN             NaN
# 7                          NaN                 NaN             NaN
# 8                          NaN                 NaN             NaN
# 9                          NaN                 NaN             NaN
# ...                        ...                 ...             ...
# 15493758                   NaN                 NaN    2.018054e+09
# 15493767                   NaN                 NaN    2.018072e+09
# 15493776                   NaN                 NaN    2.018099e+09
# 15493788                   NaN                 NaN    2.018157e+09
# 15493801                   NaN                 NaN    2.018214e+09
#
#          wipo_pub_date  patent_number patent_issue_date  \
# 3                  NaN        2480888        1949-09-06
# 4                  NaN        RE19792        1935-12-17
# 7                  NaN        6130946        2000-10-10
# 8                  NaN        2107431        1938-02-08
# 9                  NaN        2708722        1955-01-13
# ...                ...            ...               ...
# 15493758    2018-03-22            NaN               NaN
# 15493767    2018-04-19            NaN               NaN
# 15493776    2018-05-31            NaN               NaN
# 15493788    2018-08-30            NaN               NaN
# 15493801    2018-11-22            NaN               NaN
#
#                                             invention_title  \
# 3                                       BOX STAYING MACHINE
# 4                                                       NaN
# 7                                                       NaN
# 8                                     ANTISKID CROSS CHAINS
# 9                                                       NaN
# ...                                                     ...
# 15493758                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788                        STATIONARY EXERCISE MACHINE
# 15493801  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator aia_first_to_file
# 3                  UNDISCOUNTED             false
# 4                  UNDISCOUNTED               NaN
# 7                  UNDISCOUNTED             false
# 8                  UNDISCOUNTED             false
# 9                  UNDISCOUNTED             false
# ...                         ...               ...
# 15493758                  SMALL             Other
# 15493767                  SMALL             Other
# 15493776                  MICRO             Other
# 15493788           UNDISCOUNTED             Other
# 15493801                  MICRO             Other
#
# [11903819 rows x 22 columns]

# %%
print(df["appl_status_desc"].unique())
# Out:
# ['Patented File - (Old Case Added for File Tracking Purposes)'
#  'Patented Case' 'ABANDONED - RESTORED'
#  'Patent Expired Due to NonPayment of Maintenance Fees Under 37 CFR 1.362'
#  'Abandoned -- File-Wrapper-Continuation Parent Application'
#  'RO PROCESSING COMPLETED-PLACED IN STORAGE'
#  'Abandoned -- Failure to Respond to an Office Action'
#  'Abandoned -- Incomplete Application (Pre-examination)'
#  "Examiner's Answer to Appeal Brief Mailed"
#  'Expressly Abandoned -- During Examination'
#  'Allowed -- Notice of Allowance Mailed -- Issue Revision Completed'
#  "Abandoned -- After Examiner's Answer or Board of Appeals Decision"
#  'Missassigned Application Number'
#  'Expressly Abandoned -- During Publication Process'
#  'Notice of Appeal Filed' 'Abandoned -- Failure to Pay Issue Fee'
#  'Abandonment for Failure to Correct Drawings/Oath/NonPub Request'
#  'Patented File - Lapsed' 'Defensive Publication or SIR File'
#  'Patent Application Number Inactivated'
#  'Abandoned -- Incomplete (Filing Date Under Rule 53 (b) - PreExam)'
#  'Patent Reinstated Following Decision on Maintenance Fee Petition Under 37 CFR 1.377 - 1.378'
#  'Interference -- Decision on Priority Rendered by Board of Interferences'
#  'Court Proceedings Terminated'
#  'Application Involved in Court Proceedings'
#  'Response to Non-Final Office Action Entered and Forwarded to Examiner'
#  'Application Undergoing Preexam Processing'
#  'Interference -- Initial Memorandum' 'Board of Appeals Decision Rendered'
#  'Ex parte Quayle Action Mailed'
#  'Docketed New Case - Ready for Examination' 'Non Final Action Mailed'
#  'Final Rejection Mailed'
#  'Utility Application Converted to Provisional Application'
#  'Appeal Brief (or Supplemental Brief) Entered and Forwarded to Examiner'
#  'Utility Application Converted into a Provisional Application'
#  'Response after Final Action Forwarded to Examiner'
#  'Advisory Action Mailed' 'Appeal Dismissed / Withdrawn'
#  'Board of Appeals Decision Rendered after Request for Reconsideration'
#  'Withdrawn Abandonment, awaiting examiner action' 'Prosecution Suspended'
#  'Interference-Dispatch to Examiner'
#  'Publications -- Issue Fee Payment Verified'
#  'On Appeal -- Awaiting Decision by the Board of Appeals'
#  'Notice of Allowance Mailed -- Application Received in Office of Publications'
#  'AWAITING RESPONSE FOR INFORMALITY, FEE DEFICIENCY OR CRF ACTION'
#  'Publications -- Issue Fee Payment Received'
#  'Respondent brief - requester' "Examiner's answer"
#  'Appeal brief - requester' 'Awaiting TC Resp., Issue Fee Not Paid'
#  'Request Reconsideration after Board of Appeals Decision'
#  'Final Rejection Counted, Not Yet Mailed' 'Appeal Ready for Review'
#  'Amendment / Argument after Board of Appeals Decision'
#  'Remand to Examiner from Board of Appeals'
#  'Interference -- Declared by Board of Interferences'
#  'Awaiting TC Resp, Issue Fee Payment Received'
#  'Application Dispatched from Preexam, Not Yet Docketed'
#  'Reply Brief (or Supplemental Reply Brief) Forwarded to Examiner'
#  'Awaiting TC Resp, Issue Fee Payment Verified'
#  'Amendment after notice of appeal' 'Special New' 'TC Return of Appeal'
#  'Response to Ex parte Quayle Action Entered and Forwarded to Examiner'
#  'Reply Brief filed and forwarded to BPAI'
#  'Appeal Awaiting BPAI Docketing'
#  'Non Final Action Counted, Not Yet Mailed'
#  'Withdraw from issue awaiting action'
#  'SE ready for Pubs Processing -- Certificate in IFW'
#  'Response after Non-Final Action Entered (or Ready for Examiner Action)'
#  'Non-Final Action Mailed' 'Application Returned back to Preexam'
#  'Pre-Interview Communication Mailed' "Examiner's Answer Mailed"
#  'Sent to Classification contractor' 'UNDOCKETED TRACK 1'
#  'Waiting for LR clearance' 'BPAI RETURN BEFORE APPEAL'
#  'Renounced-International design application designating the U.S. renounced under the Hague Agreement'
#  'Rocket Docket' 'Hague Application under International Review'
#  'Supplemental Examination Request Filed'
#  'Receipt of Orig or Corrected Ex Parte Reexam Request'
#  'Provisional Application Expired' 'Reexamination Certificate Issued'
#  'Reexam Assigned to Examiner for Determination'
#  'Reexamination Certificate issued'
#  'Reexam Terminated -- Request Denied in Group'
#  'Response after Final Action Received'
#  'Appeal Brief Filed (or Remand from Board) - Awaiting Examiner Action'
#  'Defective Appeal Brief'
#  'Reexam Preprocessing Completed -- Released to Assigned GAU'
#  'Petition Received RE: Denial of Reexamination Request'
#  'Preprocessing Terminated--Inter Partes Reexam'
#  'Reexam Terminated -- Previous Order Vacated'
#  'Reexam -- Request Ready for Ex Parte Action'
#  'Reexam Terminated -- In Publications for Issue of a Certificate'
#  'Notice of Intent to Issue Reexam Certificate'
#  'Request for Reexamination Denied' 'Reexam Request Incomplete'
#  'Incomplete Ex Parte Reexam (Filing Date Vacated)'
#  "Petition received re':' Denial of a request for reexamination"
#  'REEXAM TERMINATED - Decision' 'Decision on Appeal Rendered by Board'
#  'Withdrawal / Dismissal of Appeal'
#  'Reexam Terminated -- Notice of Intent to Issue a Reexamination Certificate Mailed'
#  'Final Action Mailed' 'Determination - Reexamination Ordered'
#  "Reexam -- Timely Owner's Statement Received in Response to Order"
#  'Reexamination Suspended' 'Case docketed to examiner'
#  'Comments after non-final action - requester- timely'
#  'Ready for examiner action after response/comments after nonfinal'
#  'Response after non-final action - owner - timely'
#  'Ready for examiner action after owner/requester comments periods after ACP'
#  'Decision vacating reexam'
#  'Completion of pre-processing - released to TC'
#  "'Decision on Petition Denied, Reexam Request Denied, Terminated'"
#  'Comments after action closing prosecution - owner - timely'
#  'Oral hearing request - requester'
#  'Receipt of Orig or Corrected Inter Partes Reexam Request'
#  'CAFC Decision Remanded to PTAB'
#  "Examiner's determination on resp/comments aft BPAI decsn w new ground of rej (R. 1.977(d))"
#  'Petition received re":" Denial of a request for reexamination'
#  'Patent owner request for rehearing after BPAI decision (R. 1.979(a)) - timely'
#  'Oral hearing request - owner'
#  'Patent owner response after BPAI decision with new ground of rejection (R. 1.977(b))'
#  'Ready for examiner action after owner/requester N/AP and appropriate briefs'
#  'Informal response / amendment after non-final action'
#  '"Decision on Petition Denied, Reexam Request Denied, Terminated"'
#  "Owner comments on exmnr's determination aft BPAI decsn w new ground of rej (R. 1.977(e))"
#  'Notice of Appeal - owner'
#  'Ready for examiner action after BPAI decision'
#  'Request for reexamination denied'
#  'BPAI decision: New ground of rejection (R. 1.977(b))'
#  'Notice of incomplete reexam request received but no filing date accorded'
#  'Non-final action mailed'
#  'Terminated; released to Publications for issuance of Reexam Certificate'
#  'New BPAI decision after BPAI decision with new ground of rej (R. 1.977(f))'
#  'Reexamination SE Certificate'
#  'Intent to Issue Certificate based on Supplemental Exam'
#  'Ready for Reexam -- Certificate in IFW' 'Reply Brief Filed'
#  'Reexam Ordered Based on Supplemental Examination'
#  'Incomplete/Noncompliant SE Request'
#  'Docketed New SE -- Ready For Examination'
#  'PCT - International Search Report Mailed to IB'
#  'PCT - ISA Form 203 Mailed, Non-Establishment of Search Report'
#  'Search report counted' 'International Application Withdrawn'
#  'PCT - Docketed Chapter 1 Case' 'PCT Search report ready for mailing'
#  'PCT - Dispatch to TC Chapter I case' 'PCT - ISA Form Mailed'
#  'PCT - IPE Report (409) Count' 'Pre-PALM Application Added to Data Base'
#  'PCT - Formal Demand Recorded' 'PCT - Response to PCT ISA Form Entered'
#  'PCT - Receipt of IPE Demand'
#  'PCT - IPER (International Preliminary Examination Report) 409-416 Mailed'
#  'PCT - Ready for IPER or second IPE opinion'
#  'PCT - Waiting for EPO Search Report']

# %%
# df['application_number']= df['application_number'].astype(str)

# %%
df_selected = df[['appl_status_desc', 'application_number', 'application_invention_type', 'uspc_class', 'uspc_subclass', 'patent_number', 'invention_title', 'small_entity_indicator']]

# %%
df_selected
# Out:
#                                            appl_status_desc  \
# 3         Patented File - (Old Case Added for File Track...
# 4         Patented File - (Old Case Added for File Track...
# 7                                             Patented Case
# 8         Patented File - (Old Case Added for File Track...
# 9         Patented File - (Old Case Added for File Track...
# ...                                                     ...
# 15493758     PCT - International Search Report Mailed to IB
# 15493767     PCT - International Search Report Mailed to IB
# 15493776     PCT - International Search Report Mailed to IB
# 15493788     PCT - International Search Report Mailed to IB
# 15493801     PCT - International Search Report Mailed to IB
#
#          application_number application_invention_type uspc_class  \
# 3                   2045760                        NaN        NaN
# 4                   2048602                        NaN        NaN
# 7                   2107244                    Utility        380
# 8                   2122612                        NaN        000
# 9                   2122769                        NaN        NaN
# ...                     ...                        ...        ...
# 15493758     PCT/ZA17/50063                        PCT        001
# 15493767     PCT/ZA17/50076                        PCT        001
# 15493776     PCT/ZA17/50085                        PCT        001
# 15493788     PCT/ZA18/50011                        PCT        001
# 15493801     PCT/ZA18/50024                        PCT        001
#
#          uspc_subclass patent_number  \
# 3                  NaN       2480888
# 4                  NaN       RE19792
# 7               026000       6130946
# 8               000000       2107431
# 9                  NaN       2708722
# ...                ...           ...
# 15493758        PCT003           NaN
# 15493767        PCT005           NaN
# 15493776        PCT005           NaN
# 15493788        PCT003           NaN
# 15493801        PCT004           NaN
#
#                                             invention_title  \
# 3                                       BOX STAYING MACHINE
# 4                                                       NaN
# 7                                                       NaN
# 8                                     ANTISKID CROSS CHAINS
# 9                                                       NaN
# ...                                                     ...
# 15493758                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788                        STATIONARY EXERCISE MACHINE
# 15493801  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator
# 3                  UNDISCOUNTED
# 4                  UNDISCOUNTED
# 7                  UNDISCOUNTED
# 8                  UNDISCOUNTED
# 9                  UNDISCOUNTED
# ...                         ...
# 15493758                  SMALL
# 15493767                  SMALL
# 15493776                  MICRO
# 15493788           UNDISCOUNTED
# 15493801                  MICRO
#
# [11903819 rows x 8 columns]

# %%
df_selected.loc[(df_selected.appl_status_desc == 'Patented File - (Old Case Added for File Tracking Purposes)'),'appl_status_desc']='Patented Case'
df_selected
# Out:
#                                         appl_status_desc application_number  \
# 3                                          Patented Case            2045760
# 4                                          Patented Case            2048602
# 7                                          Patented Case            2107244
# 8                                          Patented Case            2122612
# 9                                          Patented Case            2122769
# ...                                                  ...                ...
# 15493758  PCT - International Search Report Mailed to IB     PCT/ZA17/50063
# 15493767  PCT - International Search Report Mailed to IB     PCT/ZA17/50076
# 15493776  PCT - International Search Report Mailed to IB     PCT/ZA17/50085
# 15493788  PCT - International Search Report Mailed to IB     PCT/ZA18/50011
# 15493801  PCT - International Search Report Mailed to IB     PCT/ZA18/50024
#
#          application_invention_type uspc_class uspc_subclass patent_number  \
# 3                               NaN        NaN           NaN       2480888
# 4                               NaN        NaN           NaN       RE19792
# 7                           Utility        380        026000       6130946
# 8                               NaN        000        000000       2107431
# 9                               NaN        NaN           NaN       2708722
# ...                             ...        ...           ...           ...
# 15493758                        PCT        001        PCT003           NaN
# 15493767                        PCT        001        PCT005           NaN
# 15493776                        PCT        001        PCT005           NaN
# 15493788                        PCT        001        PCT003           NaN
# 15493801                        PCT        001        PCT004           NaN
#
#                                             invention_title  \
# 3                                       BOX STAYING MACHINE
# 4                                                       NaN
# 7                                                       NaN
# 8                                     ANTISKID CROSS CHAINS
# 9                                                       NaN
# ...                                                     ...
# 15493758                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788                        STATIONARY EXERCISE MACHINE
# 15493801  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator
# 3                  UNDISCOUNTED
# 4                  UNDISCOUNTED
# 7                  UNDISCOUNTED
# 8                  UNDISCOUNTED
# 9                  UNDISCOUNTED
# ...                         ...
# 15493758                  SMALL
# 15493767                  SMALL
# 15493776                  MICRO
# 15493788           UNDISCOUNTED
# 15493801                  MICRO
#
# [11903819 rows x 8 columns]

# %%
df_selected.loc[(df_selected.appl_status_desc == 'Patented File - Lapsed'),'appl_status_desc']='Patented Case'
df_selected
# Out:
#                                         appl_status_desc application_number  \
# 3                                          Patented Case            2045760
# 4                                          Patented Case            2048602
# 7                                          Patented Case            2107244
# 8                                          Patented Case            2122612
# 9                                          Patented Case            2122769
# ...                                                  ...                ...
# 15493758  PCT - International Search Report Mailed to IB     PCT/ZA17/50063
# 15493767  PCT - International Search Report Mailed to IB     PCT/ZA17/50076
# 15493776  PCT - International Search Report Mailed to IB     PCT/ZA17/50085
# 15493788  PCT - International Search Report Mailed to IB     PCT/ZA18/50011
# 15493801  PCT - International Search Report Mailed to IB     PCT/ZA18/50024
#
#          application_invention_type uspc_class uspc_subclass patent_number  \
# 3                               NaN        NaN           NaN       2480888
# 4                               NaN        NaN           NaN       RE19792
# 7                           Utility        380        026000       6130946
# 8                               NaN        000        000000       2107431
# 9                               NaN        NaN           NaN       2708722
# ...                             ...        ...           ...           ...
# 15493758                        PCT        001        PCT003           NaN
# 15493767                        PCT        001        PCT005           NaN
# 15493776                        PCT        001        PCT005           NaN
# 15493788                        PCT        001        PCT003           NaN
# 15493801                        PCT        001        PCT004           NaN
#
#                                             invention_title  \
# 3                                       BOX STAYING MACHINE
# 4                                                       NaN
# 7                                                       NaN
# 8                                     ANTISKID CROSS CHAINS
# 9                                                       NaN
# ...                                                     ...
# 15493758                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788                        STATIONARY EXERCISE MACHINE
# 15493801  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator
# 3                  UNDISCOUNTED
# 4                  UNDISCOUNTED
# 7                  UNDISCOUNTED
# 8                  UNDISCOUNTED
# 9                  UNDISCOUNTED
# ...                         ...
# 15493758                  SMALL
# 15493767                  SMALL
# 15493776                  MICRO
# 15493788           UNDISCOUNTED
# 15493801                  MICRO
#
# [11903819 rows x 8 columns]

# %%
df_selected.loc[(df_selected.appl_status_desc != 'Patented Case'),'appl_status_desc']='Not Patented Case'
df_selected
# Out:
#            appl_status_desc application_number application_invention_type  \
# 3             Patented Case            2045760                        NaN
# 4             Patented Case            2048602                        NaN
# 7             Patented Case            2107244                    Utility
# 8             Patented Case            2122612                        NaN
# 9             Patented Case            2122769                        NaN
# ...                     ...                ...                        ...
# 15493758  Not Patented Case     PCT/ZA17/50063                        PCT
# 15493767  Not Patented Case     PCT/ZA17/50076                        PCT
# 15493776  Not Patented Case     PCT/ZA17/50085                        PCT
# 15493788  Not Patented Case     PCT/ZA18/50011                        PCT
# 15493801  Not Patented Case     PCT/ZA18/50024                        PCT
#
#          uspc_class uspc_subclass patent_number  \
# 3               NaN           NaN       2480888
# 4               NaN           NaN       RE19792
# 7               380        026000       6130946
# 8               000        000000       2107431
# 9               NaN           NaN       2708722
# ...             ...           ...           ...
# 15493758        001        PCT003           NaN
# 15493767        001        PCT005           NaN
# 15493776        001        PCT005           NaN
# 15493788        001        PCT003           NaN
# 15493801        001        PCT004           NaN
#
#                                             invention_title  \
# 3                                       BOX STAYING MACHINE
# 4                                                       NaN
# 7                                                       NaN
# 8                                     ANTISKID CROSS CHAINS
# 9                                                       NaN
# ...                                                     ...
# 15493758                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788                        STATIONARY EXERCISE MACHINE
# 15493801  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator
# 3                  UNDISCOUNTED
# 4                  UNDISCOUNTED
# 7                  UNDISCOUNTED
# 8                  UNDISCOUNTED
# 9                  UNDISCOUNTED
# ...                         ...
# 15493758                  SMALL
# 15493767                  SMALL
# 15493776                  MICRO
# 15493788           UNDISCOUNTED
# 15493801                  MICRO
#
# [11903819 rows x 8 columns]

# %%
df_selected_final = df_selected[['appl_status_desc', 'application_invention_type', 'uspc_class', 'uspc_subclass', 'invention_title', 'small_entity_indicator']]
df_selected_final
# Out:
#            appl_status_desc application_invention_type uspc_class  \
# 3             Patented Case                        NaN        NaN
# 4             Patented Case                        NaN        NaN
# 7             Patented Case                    Utility        380
# 8             Patented Case                        NaN        000
# 9             Patented Case                        NaN        NaN
# ...                     ...                        ...        ...
# 15493758  Not Patented Case                        PCT        001
# 15493767  Not Patented Case                        PCT        001
# 15493776  Not Patented Case                        PCT        001
# 15493788  Not Patented Case                        PCT        001
# 15493801  Not Patented Case                        PCT        001
#
#          uspc_subclass                                    invention_title  \
# 3                  NaN                                BOX STAYING MACHINE
# 4                  NaN                                                NaN
# 7               026000                                                NaN
# 8               000000                              ANTISKID CROSS CHAINS
# 9                  NaN                                                NaN
# ...                ...                                                ...
# 15493758        PCT003                     A MODULAR ENTERTAINMENT SYSTEM
# 15493767        PCT005  MASTER MESSAGING AND CONTROL SYSTEM FOR INDUST...
# 15493776        PCT005  GEOSPATIAL LOCATION VERIFICATION WITH REFERENC...
# 15493788        PCT003                        STATIONARY EXERCISE MACHINE
# 15493801        PCT004  DIGITAL DATA MINUTIAE PROCESSING FOR THE ANALY...
#
#          small_entity_indicator
# 3                  UNDISCOUNTED
# 4                  UNDISCOUNTED
# 7                  UNDISCOUNTED
# 8                  UNDISCOUNTED
# 9                  UNDISCOUNTED
# ...                         ...
# 15493758                  SMALL
# 15493767                  SMALL
# 15493776                  MICRO
# 15493788           UNDISCOUNTED
# 15493801                  MICRO
#
# [11903819 rows x 6 columns]

# %% [markdown]
# Data Pre-Processing

# %%
# Since there are 15million+ rows, I use a sample of 0.002 of the 15million+ rows 
df_selected_final_sample = df_selected_final.sample(frac=.002)
df_selected_final_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23808 entries, 10657935 to 8629055
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appl_status_desc            23808 non-null  object
#  1   application_invention_type  23801 non-null  object
#  2   uspc_class                  21214 non-null  object
#  3   uspc_subclass               21114 non-null  object
#  4   invention_title             23794 non-null  object
#  5   small_entity_indicator      23808 non-null  object
# dtypes: object(6)
# memory usage: 1.3+ MB

# %%
# Convert categorical data into a numerical form and our machine learning algorithm can take in that as input.
test = pd.get_dummies(df_selected_final_sample, columns=['application_invention_type', 'uspc_class', 'uspc_subclass', 'invention_title', 'small_entity_indicator'])

# %%
X = test
y = df_selected_final_sample["appl_status_desc"]
print(X.shape, y.shape)
# Out:
# (23808, 27490) (23808,)

# %%
X
# Out:
#            appl_status_desc  application_invention_type_Design  \
# 10657935  Not Patented Case                                  0
# 6299094       Patented Case                                  0
# 7396370   Not Patented Case                                  0
# 1203000       Patented Case                                  0
# 959111    Not Patented Case                                  0
# ...                     ...                                ...
# 9577869       Patented Case                                  1
# 8831662   Not Patented Case                                  0
# 9354261       Patented Case                                  1
# 3512258   Not Patented Case                                  0
# 8629055       Patented Case                                  0
#
#           application_invention_type_PCT  application_invention_type_Plant  \
# 10657935                               0                                 0
# 6299094                                0                                 0
# 7396370                                0                                 0
# 1203000                                0                                 0
# 959111                                 0                                 0
# ...                                  ...                               ...
# 9577869                                0                                 0
# 8831662                                0                                 0
# 9354261                                0                                 0
# 3512258                                0                                 0
# 8629055                                0                                 0
#
#           application_invention_type_Provisional  \
# 10657935                                       1
# 6299094                                        0
# 7396370                                        0
# 1203000                                        0
# 959111                                         0
# ...                                          ...
# 9577869                                        0
# 8831662                                        0
# 9354261                                        0
# 3512258                                        0
# 8629055                                        0
#
#           application_invention_type_Re-Examination  \
# 10657935                                          0
# 6299094                                           0
# 7396370                                           0
# 1203000                                           0
# 959111                                            0
# ...                                             ...
# 9577869                                           0
# 8831662                                           0
# 9354261                                           0
# 3512258                                           0
# 8629055                                           0
#
#           application_invention_type_Re-Issue  \
# 10657935                                    0
# 6299094                                     0
# 7396370                                     0
# 1203000                                     0
# 959111                                      0
# ...                                       ...
# 9577869                                     0
# 8831662                                     0
# 9354261                                     0
# 3512258                                     0
# 8629055                                     0
#
#           application_invention_type_Utility  uspc_class_0.0  uspc_class_1.0  \
# 10657935                                   0               0               0
# 6299094                                    1               0               0
# 7396370                                    1               0               0
# 1203000                                    1               0               0
# 959111                                     1               0               0
# ...                                      ...             ...             ...
# 9577869                                    0               0               0
# 8831662                                    1               0               0
# 9354261                                    0               0               0
# 3512258                                    1               0               0
# 8629055                                    1               0               0
#
#           ...  \
# 10657935  ...
# 6299094   ...
# 7396370   ...
# 1203000   ...
# 959111    ...
# ...       ...
# 9577869   ...
# 8831662   ...
# 9354261   ...
# 3512258   ...
# 8629055   ...
#
#           invention_title_Zoom lens drive system for lens shutter type of camera  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_[1]BENZOTHIENO[3,2-B][1]BENZOTHIOPHENE COMPOUND AND METHOD FOR PRODUCING THE SAME, AND ORGANIC ELECTRONIC DEVICE USING THE SAME  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_[THIN FILM TRANSISTOR AND PIXEL STRUCTURE THEREOF]  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_hand operated peeler  \
# 10657935                                     0
# 6299094                                      0
# 7396370                                      0
# 1203000                                      0
# 959111                                       0
# ...                                        ...
# 9577869                                      0
# 8831662                                      0
# 9354261                                      0
# 3512258                                      0
# 8629055                                      0
#
#           invention_title_mRNA FOR USE IN TREATMENT OF HUMAN GENETIC DISEASES  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_percutaneous electrode nerve stimulation needle guidance system  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_weatherstrip, composition including silane-grafted polyolefin, and process of making a weatherstrip  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           small_entity_indicator_MICRO  small_entity_indicator_SMALL  \
# 10657935                             0                             0
# 6299094                              0                             0
# 7396370                              0                             0
# 1203000                              0                             0
# 959111                               0                             1
# ...                                ...                           ...
# 9577869                              0                             1
# 8831662                              0                             0
# 9354261                              0                             0
# 3512258                              0                             0
# 8629055                              0                             1
#
#           small_entity_indicator_UNDISCOUNTED
# 10657935                                    1
# 6299094                                     1
# 7396370                                     1
# 1203000                                     1
# 959111                                      0
# ...                                       ...
# 9577869                                     0
# 8831662                                     1
# 9354261                                     1
# 3512258                                     1
# 8629055                                     0
#
# [23808 rows x 27490 columns]

# %%
X = X.iloc[:,1:]

# %%
X
# Out:
#           application_invention_type_Design  application_invention_type_PCT  \
# 10657935                                  0                               0
# 6299094                                   0                               0
# 7396370                                   0                               0
# 1203000                                   0                               0
# 959111                                    0                               0
# ...                                     ...                             ...
# 9577869                                   1                               0
# 8831662                                   0                               0
# 9354261                                   1                               0
# 3512258                                   0                               0
# 8629055                                   0                               0
#
#           application_invention_type_Plant  \
# 10657935                                 0
# 6299094                                  0
# 7396370                                  0
# 1203000                                  0
# 959111                                   0
# ...                                    ...
# 9577869                                  0
# 8831662                                  0
# 9354261                                  0
# 3512258                                  0
# 8629055                                  0
#
#           application_invention_type_Provisional  \
# 10657935                                       1
# 6299094                                        0
# 7396370                                        0
# 1203000                                        0
# 959111                                         0
# ...                                          ...
# 9577869                                        0
# 8831662                                        0
# 9354261                                        0
# 3512258                                        0
# 8629055                                        0
#
#           application_invention_type_Re-Examination  \
# 10657935                                          0
# 6299094                                           0
# 7396370                                           0
# 1203000                                           0
# 959111                                            0
# ...                                             ...
# 9577869                                           0
# 8831662                                           0
# 9354261                                           0
# 3512258                                           0
# 8629055                                           0
#
#           application_invention_type_Re-Issue  \
# 10657935                                    0
# 6299094                                     0
# 7396370                                     0
# 1203000                                     0
# 959111                                      0
# ...                                       ...
# 9577869                                     0
# 8831662                                     0
# 9354261                                     0
# 3512258                                     0
# 8629055                                     0
#
#           application_invention_type_Utility  uspc_class_0.0  uspc_class_1.0  \
# 10657935                                   0               0               0
# 6299094                                    1               0               0
# 7396370                                    1               0               0
# 1203000                                    1               0               0
# 959111                                     1               0               0
# ...                                      ...             ...             ...
# 9577869                                    0               0               0
# 8831662                                    1               0               0
# 9354261                                    0               0               0
# 3512258                                    1               0               0
# 8629055                                    1               0               0
#
#           uspc_class_2.0  ...  \
# 10657935               0  ...
# 6299094                0  ...
# 7396370                0  ...
# 1203000                0  ...
# 959111                 0  ...
# ...                  ...  ...
# 9577869                0  ...
# 8831662                0  ...
# 9354261                0  ...
# 3512258                0  ...
# 8629055                0  ...
#
#           invention_title_Zoom lens drive system for lens shutter type of camera  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_[1]BENZOTHIENO[3,2-B][1]BENZOTHIOPHENE COMPOUND AND METHOD FOR PRODUCING THE SAME, AND ORGANIC ELECTRONIC DEVICE USING THE SAME  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_[THIN FILM TRANSISTOR AND PIXEL STRUCTURE THEREOF]  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_hand operated peeler  \
# 10657935                                     0
# 6299094                                      0
# 7396370                                      0
# 1203000                                      0
# 959111                                       0
# ...                                        ...
# 9577869                                      0
# 8831662                                      0
# 9354261                                      0
# 3512258                                      0
# 8629055                                      0
#
#           invention_title_mRNA FOR USE IN TREATMENT OF HUMAN GENETIC DISEASES  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_percutaneous electrode nerve stimulation needle guidance system  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           invention_title_weatherstrip, composition including silane-grafted polyolefin, and process of making a weatherstrip  \
# 10657935                                                  0
# 6299094                                                   0
# 7396370                                                   0
# 1203000                                                   0
# 959111                                                    0
# ...                                                     ...
# 9577869                                                   0
# 8831662                                                   0
# 9354261                                                   0
# 3512258                                                   0
# 8629055                                                   0
#
#           small_entity_indicator_MICRO  small_entity_indicator_SMALL  \
# 10657935                             0                             0
# 6299094                              0                             0
# 7396370                              0                             0
# 1203000                              0                             0
# 959111                               0                             1
# ...                                ...                           ...
# 9577869                              0                             1
# 8831662                              0                             0
# 9354261                              0                             0
# 3512258                              0                             0
# 8629055                              0                             1
#
#           small_entity_indicator_UNDISCOUNTED
# 10657935                                    1
# 6299094                                     1
# 7396370                                     1
# 1203000                                     1
# 959111                                      0
# ...                                       ...
# 9577869                                     0
# 8831662                                     1
# 9354261                                     1
# 3512258                                     1
# 8629055                                     0
#
# [23808 rows x 27489 columns]

# %%
y
# Out:
# 10657935    Not Patented Case
# 6299094         Patented Case
# 7396370     Not Patented Case
# 1203000         Patented Case
# 959111      Not Patented Case
#                   ...
# 9577869         Patented Case
# 8831662     Not Patented Case
# 9354261         Patented Case
# 3512258     Not Patented Case
# 8629055         Patented Case
# Name: appl_status_desc, Length: 23808, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
# Split X, y to test and train
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
# Get a general score of the model
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier(n_jobs=-1)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.6710349462365591

# %% [markdown]
# # Train the Model
# Using a logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Initialize model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Score the model
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.920866935483871
# Testing Data Score: 0.676747311827957

# %% [markdown]
# # Predict

# %%
predictions = model.predict(X_test)
df_pred = pd.DataFrame({"Actual":y_test, "Predicted":predictions}) 
df_pred
# Out:
#                     Actual          Predicted
# 6511686      Patented Case  Not Patented Case
# 5340633  Not Patented Case  Not Patented Case
# 2138717  Not Patented Case  Not Patented Case
# 4636930  Not Patented Case  Not Patented Case
# 5312072      Patented Case  Not Patented Case
# ...                    ...                ...
# 7000487      Patented Case  Not Patented Case
# 2839035  Not Patented Case  Not Patented Case
# 2756698  Not Patented Case  Not Patented Case
# 3445297      Patented Case  Not Patented Case
# 9520286      Patented Case      Patented Case
#
# [5952 rows x 2 columns]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# Create the GridSearchCV model
param_grid = {'C':np.logspace(-4, 4, 20),
             'penalty':['l1','l2']}

grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
best_model = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ................C=0.0001, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ................C=0.0001, penalty=l1;, score=nan total time=   1.2s
# [CV 3/5] END ................C=0.0001, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ................C=0.0001, penalty=l1;, score=nan total time=   1.4s
# [CV 5/5] END ................C=0.0001, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ..............C=0.0001, penalty=l2;, score=0.583 total time=  14.5s
# [CV 2/5] END ..............C=0.0001, penalty=l2;, score=0.583 total time=  10.5s
# [CV 3/5] END ..............C=0.0001, penalty=l2;, score=0.583 total time=  12.3s
# [CV 4/5] END ..............C=0.0001, penalty=l2;, score=0.583 total time=  14.1s
# [CV 5/5] END ..............C=0.0001, penalty=l2;, score=0.583 total time=  14.5s
# [CV 1/5] END C=0.00026366508987303583, penalty=l1;, score=nan total time=   1.2s
# [CV 2/5] END C=0.00026366508987303583, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END C=0.00026366508987303583, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END C=0.00026366508987303583, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END C=0.00026366508987303583, penalty=l1;, score=nan total time=   1.4s
# [CV 1/5] END C=0.00026366508987303583, penalty=l2;, score=0.583 total time=  13.9s
# [CV 2/5] END C=0.00026366508987303583, penalty=l2;, score=0.583 total time=  14.5s
# [CV 3/5] END C=0.00026366508987303583, penalty=l2;, score=0.583 total time=  14.6s
# [CV 4/5] END C=0.00026366508987303583, penalty=l2;, score=0.583 total time=  14.6s
# [CV 5/5] END C=0.00026366508987303583, penalty=l2;, score=0.583 total time=  15.1s
# [CV 1/5] END .C=0.0006951927961775605, penalty=l1;, score=nan total time=   1.4s
# [CV 2/5] END .C=0.0006951927961775605, penalty=l1;, score=nan total time=   1.4s
# [CV 3/5] END .C=0.0006951927961775605, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .C=0.0006951927961775605, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .C=0.0006951927961775605, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END C=0.0006951927961775605, penalty=l2;, score=0.583 total time=  14.3s
# [CV 2/5] END C=0.0006951927961775605, penalty=l2;, score=0.583 total time=  14.7s
# [CV 3/5] END C=0.0006951927961775605, penalty=l2;, score=0.583 total time=  15.1s
# [CV 4/5] END C=0.0006951927961775605, penalty=l2;, score=0.583 total time=  14.2s
# [CV 5/5] END C=0.0006951927961775605, penalty=l2;, score=0.583 total time=  15.7s
# [CV 1/5] END .C=0.0018329807108324356, penalty=l1;, score=nan total time=   1.4s
# [CV 2/5] END .C=0.0018329807108324356, penalty=l1;, score=nan total time=   1.4s
# [CV 3/5] END .C=0.0018329807108324356, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .C=0.0018329807108324356, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .C=0.0018329807108324356, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END C=0.0018329807108324356, penalty=l2;, score=0.608 total time=  14.2s
# [CV 2/5] END C=0.0018329807108324356, penalty=l2;, score=0.607 total time=  13.3s
# [CV 3/5] END C=0.0018329807108324356, penalty=l2;, score=0.615 total time=  15.9s
# [CV 4/5] END C=0.0018329807108324356, penalty=l2;, score=0.614 total time=  14.4s
# [CV 5/5] END C=0.0018329807108324356, penalty=l2;, score=0.610 total time=  15.4s
# [CV 1/5] END ..C=0.004832930238571752, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ..C=0.004832930238571752, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ..C=0.004832930238571752, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ..C=0.004832930238571752, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ..C=0.004832930238571752, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END C=0.004832930238571752, penalty=l2;, score=0.650 total time=  16.6s
# [CV 2/5] END C=0.004832930238571752, penalty=l2;, score=0.654 total time=  16.1s
# [CV 3/5] END C=0.004832930238571752, penalty=l2;, score=0.670 total time=  17.0s
# [CV 4/5] END C=0.004832930238571752, penalty=l2;, score=0.656 total time=  16.7s
# [CV 5/5] END C=0.004832930238571752, penalty=l2;, score=0.669 total time=  17.8s
# [CV 1/5] END ..C=0.012742749857031334, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ..C=0.012742749857031334, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ..C=0.012742749857031334, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ..C=0.012742749857031334, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ..C=0.012742749857031334, penalty=l1;, score=nan total time=   1.2s
# [CV 1/5] END C=0.012742749857031334, penalty=l2;, score=0.673 total time=  17.8s
# [CV 2/5] END C=0.012742749857031334, penalty=l2;, score=0.685 total time=  17.3s
# [CV 3/5] END C=0.012742749857031334, penalty=l2;, score=0.678 total time=  16.9s
# [CV 4/5] END C=0.012742749857031334, penalty=l2;, score=0.680 total time=  16.9s
# [CV 5/5] END C=0.012742749857031334, penalty=l2;, score=0.674 total time=  17.1s
# [CV 1/5] END ...C=0.03359818286283781, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ...C=0.03359818286283781, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ...C=0.03359818286283781, penalty=l1;, score=nan total time=   1.2s
# [CV 4/5] END ...C=0.03359818286283781, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ...C=0.03359818286283781, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END .C=0.03359818286283781, penalty=l2;, score=0.669 total time=  20.4s
# [CV 2/5] END .C=0.03359818286283781, penalty=l2;, score=0.683 total time=  19.9s
# [CV 3/5] END .C=0.03359818286283781, penalty=l2;, score=0.679 total time=  20.1s
# [CV 4/5] END .C=0.03359818286283781, penalty=l2;, score=0.685 total time=  19.3s
# [CV 5/5] END .C=0.03359818286283781, penalty=l2;, score=0.674 total time=  20.6s
# [CV 1/5] END ...C=0.08858667904100823, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ...C=0.08858667904100823, penalty=l1;, score=nan total time=   1.2s
# [CV 3/5] END ...C=0.08858667904100823, penalty=l1;, score=nan total time=   1.2s
# [CV 4/5] END ...C=0.08858667904100823, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ...C=0.08858667904100823, penalty=l1;, score=nan total time=   1.2s
# [CV 1/5] END .C=0.08858667904100823, penalty=l2;, score=0.670 total time=  21.6s
# [CV 2/5] END .C=0.08858667904100823, penalty=l2;, score=0.687 total time=  19.1s
# [CV 3/5] END .C=0.08858667904100823, penalty=l2;, score=0.684 total time=  23.3s
# [CV 4/5] END .C=0.08858667904100823, penalty=l2;, score=0.687 total time=  21.6s
# [CV 5/5] END .C=0.08858667904100823, penalty=l2;, score=0.684 total time=  21.9s
# [CV 1/5] END ...C=0.23357214690901212, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ...C=0.23357214690901212, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ...C=0.23357214690901212, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ...C=0.23357214690901212, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ...C=0.23357214690901212, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END .C=0.23357214690901212, penalty=l2;, score=0.673 total time=  28.6s
# [CV 2/5] END .C=0.23357214690901212, penalty=l2;, score=0.686 total time=  27.0s
# [CV 3/5] END .C=0.23357214690901212, penalty=l2;, score=0.681 total time=  24.7s
# [CV 4/5] END .C=0.23357214690901212, penalty=l2;, score=0.685 total time=  28.0s
# [CV 5/5] END .C=0.23357214690901212, penalty=l2;, score=0.679 total time=  30.0s
# [CV 1/5] END .....C=0.615848211066026, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END .....C=0.615848211066026, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END .....C=0.615848211066026, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .....C=0.615848211066026, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .....C=0.615848211066026, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ...C=0.615848211066026, penalty=l2;, score=0.671 total time=  37.2s
# [CV 2/5] END ...C=0.615848211066026, penalty=l2;, score=0.682 total time=  36.2s
# [CV 3/5] END ...C=0.615848211066026, penalty=l2;, score=0.679 total time=  35.0s
# [CV 4/5] END ...C=0.615848211066026, penalty=l2;, score=0.679 total time=  36.4s
# [CV 5/5] END ...C=0.615848211066026, penalty=l2;, score=0.673 total time=  37.1s
# [CV 1/5] END .....C=1.623776739188721, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END .....C=1.623776739188721, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END .....C=1.623776739188721, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .....C=1.623776739188721, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .....C=1.623776739188721, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ...C=1.623776739188721, penalty=l2;, score=0.672 total time=  39.6s
# [CV 2/5] END ...C=1.623776739188721, penalty=l2;, score=0.678 total time=  38.2s
# [CV 3/5] END ...C=1.623776739188721, penalty=l2;, score=0.675 total time=  39.7s
# [CV 4/5] END ...C=1.623776739188721, penalty=l2;, score=0.675 total time=  39.5s
# [CV 5/5] END ...C=1.623776739188721, penalty=l2;, score=0.671 total time=  38.0s
# [CV 1/5] END .....C=4.281332398719396, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END .....C=4.281332398719396, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END .....C=4.281332398719396, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .....C=4.281332398719396, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .....C=4.281332398719396, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ...C=4.281332398719396, penalty=l2;, score=0.669 total time=  38.4s
# [CV 2/5] END ...C=4.281332398719396, penalty=l2;, score=0.675 total time=  40.4s
# [CV 3/5] END ...C=4.281332398719396, penalty=l2;, score=0.674 total time=  37.9s
# [CV 4/5] END ...C=4.281332398719396, penalty=l2;, score=0.674 total time=  38.0s
# [CV 5/5] END ...C=4.281332398719396, penalty=l2;, score=0.668 total time=  37.7s
# [CV 1/5] END ....C=11.288378916846883, penalty=l1;, score=nan total time=   1.2s
# [CV 2/5] END ....C=11.288378916846883, penalty=l1;, score=nan total time=   1.2s
# [CV 3/5] END ....C=11.288378916846883, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ....C=11.288378916846883, penalty=l1;, score=nan total time=   1.2s
# [CV 5/5] END ....C=11.288378916846883, penalty=l1;, score=nan total time=   1.2s
# [CV 1/5] END ..C=11.288378916846883, penalty=l2;, score=0.669 total time=  37.1s
# [CV 2/5] END ..C=11.288378916846883, penalty=l2;, score=0.675 total time=  37.9s
# [CV 3/5] END ..C=11.288378916846883, penalty=l2;, score=0.672 total time=  38.5s
# [CV 4/5] END ..C=11.288378916846883, penalty=l2;, score=0.672 total time=  36.4s
# [CV 5/5] END ..C=11.288378916846883, penalty=l2;, score=0.667 total time=  38.7s
# [CV 1/5] END ....C=29.763514416313132, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ....C=29.763514416313132, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ....C=29.763514416313132, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ....C=29.763514416313132, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ....C=29.763514416313132, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ..C=29.763514416313132, penalty=l2;, score=0.667 total time=  38.6s
# [CV 2/5] END ..C=29.763514416313132, penalty=l2;, score=0.672 total time=  39.1s
# [CV 3/5] END ..C=29.763514416313132, penalty=l2;, score=0.677 total time=  37.6s
# [CV 4/5] END ..C=29.763514416313132, penalty=l2;, score=0.671 total time=  38.6s
# [CV 5/5] END ..C=29.763514416313132, penalty=l2;, score=0.668 total time=  39.2s
# [CV 1/5] END .....C=78.47599703514607, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END .....C=78.47599703514607, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END .....C=78.47599703514607, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .....C=78.47599703514607, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .....C=78.47599703514607, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ...C=78.47599703514607, penalty=l2;, score=0.668 total time=  39.4s
# [CV 2/5] END ...C=78.47599703514607, penalty=l2;, score=0.670 total time=  38.7s
# [CV 3/5] END ...C=78.47599703514607, penalty=l2;, score=0.675 total time=  37.2s
# [CV 4/5] END ...C=78.47599703514607, penalty=l2;, score=0.670 total time=  40.3s
# [CV 5/5] END ...C=78.47599703514607, penalty=l2;, score=0.661 total time=  42.4s
# [CV 1/5] END ......C=206.913808111479, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END ......C=206.913808111479, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ......C=206.913808111479, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ......C=206.913808111479, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ......C=206.913808111479, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ....C=206.913808111479, penalty=l2;, score=0.667 total time=  38.1s
# [CV 2/5] END ....C=206.913808111479, penalty=l2;, score=0.672 total time=  42.4s
# [CV 3/5] END ....C=206.913808111479, penalty=l2;, score=0.679 total time=  38.2s
# [CV 4/5] END ....C=206.913808111479, penalty=l2;, score=0.670 total time=  39.6s
# [CV 5/5] END ....C=206.913808111479, penalty=l2;, score=0.659 total time=  41.0s
# [CV 1/5] END .....C=545.5594781168514, penalty=l1;, score=nan total time=   1.3s
# [CV 2/5] END .....C=545.5594781168514, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END .....C=545.5594781168514, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END .....C=545.5594781168514, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END .....C=545.5594781168514, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ...C=545.5594781168514, penalty=l2;, score=0.663 total time=  44.0s
# [CV 2/5] END ...C=545.5594781168514, penalty=l2;, score=0.674 total time=  41.1s
# [CV 3/5] END ...C=545.5594781168514, penalty=l2;, score=0.675 total time= 1.7min
# [CV 4/5] END ...C=545.5594781168514, penalty=l2;, score=0.664 total time=  37.6s
# [CV 5/5] END ...C=545.5594781168514, penalty=l2;, score=0.659 total time=  40.0s
# [CV 1/5] END ......C=1438.44988828766, penalty=l1;, score=nan total time=   1.4s
# [CV 2/5] END ......C=1438.44988828766, penalty=l1;, score=nan total time=   1.3s
# [CV 3/5] END ......C=1438.44988828766, penalty=l1;, score=nan total time=   1.3s
# [CV 4/5] END ......C=1438.44988828766, penalty=l1;, score=nan total time=   1.3s
# [CV 5/5] END ......C=1438.44988828766, penalty=l1;, score=nan total time=   1.3s
# [CV 1/5] END ....C=1438.44988828766, penalty=l2;, score=0.661 total time=  37.5s
# [CV 2/5] END ....C=1438.44988828766, penalty=l2;, score=0.672 total time=  40.6s
# [CV 3/5] END ....C=1438.44988828766, penalty=l2;, score=0.674 total time=  38.9s
# [CV 4/5] END ....C=1438.44988828766, penalty=l2;, score=0.666 total time=  40.7s
# [CV 5/5] END ....C=1438.44988828766, penalty=l2;, score=0.663 total time=  40.9s
# [CV 1/5] END .....C=3792.690190732246, penalty=l1;, score=nan total time=   1.5s
# [CV 2/5] END .....C=3792.690190732246, penalty=l1;, score=nan total time=   1.6s
# [CV 3/5] END .....C=3792.690190732246, penalty=l1;, score=nan total time=   1.5s
# [CV 4/5] END .....C=3792.690190732246, penalty=l1;, score=nan total time=   1.5s
# [CV 5/5] END .....C=3792.690190732246, penalty=l1;, score=nan total time=   1.5s
# [CV 1/5] END ...C=3792.690190732246, penalty=l2;, score=0.661 total time=  36.3s
# [CV 2/5] END ...C=3792.690190732246, penalty=l2;, score=0.670 total time=  39.9s
# [CV 3/5] END ...C=3792.690190732246, penalty=l2;, score=0.673 total time=  41.4s
# [CV 4/5] END ...C=3792.690190732246, penalty=l2;, score=0.665 total time=  39.7s
# [CV 5/5] END ...C=3792.690190732246, penalty=l2;, score=0.659 total time=  40.0s
# [CV 1/5] END ...............C=10000.0, penalty=l1;, score=nan total time=   1.4s
# [CV 2/5] END ...............C=10000.0, penalty=l1;, score=nan total time=   1.4s
# [CV 3/5] END ...............C=10000.0, penalty=l1;, score=nan total time=   3.0s
# [CV 4/5] END ...............C=10000.0, penalty=l1;, score=nan total time=   3.2s
# [CV 5/5] END ...............C=10000.0, penalty=l1;, score=nan total time=   3.5s
# [CV 1/5] END .............C=10000.0, penalty=l2;, score=0.656 total time= 1.5min
# [CV 2/5] END .............C=10000.0, penalty=l2;, score=0.664 total time=  36.4s
# [CV 3/5] END .............C=10000.0, penalty=l2;, score=0.679 total time=  37.8s
# [CV 4/5] END .............C=10000.0, penalty=l2;, score=0.666 total time=  34.1s
# [CV 5/5] END .............C=10000.0, penalty=l2;, score=0.659 total time=  37.1s

# %%
print(best_model.best_params_)
print('Best Score: ', best_model.best_score_)
# Out:
# {'C': 0.08858667904100823, 'penalty': 'l2'}
# Best Score:  0.6825723610909458

# %%
# Make predictions
grid_predictions = best_model.predict(X_test)
df_grid = pd.DataFrame({"Actual":y_test, "Predicted":grid_predictions}) 
df_grid.head()
# Out:
#                     Actual          Predicted
# 6511686      Patented Case  Not Patented Case
# 5340633  Not Patented Case  Not Patented Case
# 2138717  Not Patented Case  Not Patented Case
# 4636930  Not Patented Case  Not Patented Case
# 5312072      Patented Case  Not Patented Case

# %%
# Score the model
best_model.score(X_test, y_test)
# Out:
# 0.6802755376344086

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, grid_predictions))
# Out:
#                    precision    recall  f1-score   support
#
# Not Patented Case       0.74      0.71      0.72      3509
#     Patented Case       0.61      0.63      0.62      2443
#
#          accuracy                           0.68      5952
#         macro avg       0.67      0.67      0.67      5952
#      weighted avg       0.68      0.68      0.68      5952
