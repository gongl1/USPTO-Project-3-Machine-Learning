# %%
# pip install splinter

# %%
# pip install webdriver_manager

# %%
from bs4 import BeautifulSoup
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\gongl\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
urls = [
        'https://patents.google.com/patent/USRE29872E/en?oq=USRE29872E', 
        'https://patents.google.com/patent/USRE29993E/en?oq=USRE29993E', 
        'https://patents.google.com/patent/USRE30120E/en?oq=USRE30120E',
        'https://patents.google.com/patent/USRE30135E/en?oq=USRE30135E',
        'https://patents.google.com/patent/USRE30334E/en?oq=USRE30334E',
        'https://patents.google.com/patent/USRE30423E/en?oq=USRE30423E',
        'https://patents.google.com/patent/USRE30440E/en?oq=USRE30440E',
        'https://patents.google.com/patent/USRE30525E/en?oq=USRE30525E',
        'https://patents.google.com/patent/USRE30932E/en?oq=USRE30932E',
        'https://patents.google.com/patent/USRE30981E/en?oq=USRE30981E',
        'https://patents.google.com/patent/USRE31154E/en?oq=USRE31154E',
        'https://patents.google.com/patent/USRE31196E/en?oq=USRE31196E',
        'https://patents.google.com/patent/USRE31296E/en?oq=USRE31296E',
        'https://patents.google.com/patent/USRE31361E/en?oq=USRE31361E',
        'https://patents.google.com/patent/USRE31451E/en?oq=USRE31451E',
        'https://patents.google.com/patent/USRE31627E/en?oq=USRE31627E',
        'https://patents.google.com/patent/USRE31713E/en?oq=USRE31713E',
        'https://patents.google.com/patent/USRE31956E/en?oq=USRE31956E',
        'https://patents.google.com/patent/USRE32125E/en?oq=USRE32125E',
        'https://patents.google.com/patent/USRE32175E/en?oq=USRE32175E',
        'https://patents.google.com/patent/USRE32433E/en?oq=USRE32433E',
        'https://patents.google.com/patent/USRE32546E/en?oq=USRE32546E',
        'https://patents.google.com/patent/USRE33058E/en?oq=USRE33058E',
        'https://patents.google.com/patent/USRE33126E/en?oq=USRE33126E',
        'https://patents.google.com/patent/USRE33551E/en?oq=USRE33551E',
        'https://patents.google.com/patent/USRE33950E/en?oq=USRE33950E',
        'https://patents.google.com/patent/USRE34023E/en?oq=USRE34023E',
        'https://patents.google.com/patent/USRE34064E/en?oq=USRE34064E',
        'https://patents.google.com/patent/USRE34142E/en?oq=USRE34142E',
        'https://patents.google.com/patent/USRE34146E/en?oq=USRE34146E',
        'https://patents.google.com/patent/USRE34260E/en?oq=USRE34260E',
        'https://patents.google.com/patent/USRE34359E/en?oq=USRE34359E',
        'https://patents.google.com/patent/USRE34493E/en?oq=USRE34493E',
        'https://patents.google.com/patent/USRE34565E/en?oq=USRE34565E',
        'https://patents.google.com/patent/USRE35425E/en?oq=USRE35425E',
        'https://patents.google.com/patent/USRE36722E/en?oq=USRE36722E',
        'https://patents.google.com/patent/USRE37731E1/en?oq=USRE37731E1',
        'https://patents.google.com/patent/USRE38615E1/en?oq=USRE38615E1',
        'https://patents.google.com/patent/USRE38691E1/en?oq=USRE38691E1',
        'https://patents.google.com/patent/USRE39327E1/en?oq=USRE39327E1',
        'https://patents.google.com/patent/USRE39440E1/en?oq=USRE39440E1',
        'https://patents.google.com/patent/USRE39487E1/en?oq=USRE39487E1',
        'https://patents.google.com/patent/USRE39598E1/en?oq=USRE39598E1',
        'https://patents.google.com/patent/USRE39669E1/en?oq=USRE39669E1',
        'https://patents.google.com/patent/USRE39757E1/en?oq=USRE39757E1',
        'https://patents.google.com/patent/USRE40615E1/en?oq=USRE40615E1',
        'https://patents.google.com/patent/USRE42607E1/en?oq=USRE42607E1',
        'https://patents.google.com/patent/USRE42767E1/en?oq=USRE42767E1',
        'https://patents.google.com/patent/USRE43074E1/en?oq=USRE43074E1',
        'https://patents.google.com/patent/USRE44839E1/en?oq=USRE44839E1'
       ]
# browser.visit(url)

# %%
len(urls)
# Out:
# 50

# %%
finalresult = []

# %%
for url in urls:
    browser.visit(url)
    html_hemispheres = browser.html
    soup = BeautifulSoup(html_hemispheres, 'html.parser')
    
    # Retreive all items that contain
    items = soup.find_all(class_='claim-text style-scope patent-text')
    
    text = str(items).split('<div class="claim-text style-scope patent-text">')
    pure = text[1:]
    replaced = [line.replace("</div>\n", "") for line in pure]
    replaced = [line.replace("</div>", "") for line in replaced]
    replaced = [line.replace("</div>,", "") for line in replaced]
    finalresult.append(replaced)

# %%
finalresult
# Out:
# [['1. A differential gear mechanism comprising a differential gear case defining a gear chamber, differential gear means located in said gear chamber, said differential gear means including at least one input gear and a pair of output gears, lockup means for locking up said differential gear means to retard differentiating action, and actuator means for actuating said lockup means, said lockup means including a member rotatable relative to said actuator means upon differentiating action occurring, and said actuator means including an oscillating weight engageable with said member upon rotation thereof relative to said actuator means to retard rotation thereof, and means for moving said member to actuate said lockup means upon a predetermined degree of retardation of rotation of said member., ',
#   '2. A differential gear mechanism as defined in claim 1 wherein said lockup means comprises a clutch means for drivingly coupling said case and one of said output gears., ',
# ...

# %%
len(finalresult)
# Out:
# 50

# %%
finalresult[2]
